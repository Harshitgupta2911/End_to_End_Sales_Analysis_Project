# %%
# !pip install pandas numpy matplotlib 
# %pip install seaborn




import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\End_toEnd_Sales_Project\superstore.csv")

# %%
df.head(5)
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %%
df['Discount'].describe()
# Out:
# count    51290.000000
# mean         0.142908
# std          0.212280
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.200000
# max          0.850000
# Name: Discount, dtype: float64

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', '记录数', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df=df.drop(columns='记录数')

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df["Market2"]
# Out:
# 0        North America
# 1        North America
# 2        North America
# 3        North America
# 4        North America
#              ...
# 51285    North America
# 51286    North America
# 51287    North America
# 51288    North America
# 51289    North America
# Name: Market2, Length: 51290, dtype: object

# %%
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['category', 'city', 'country', 'customer.id', 'customer.name',
#        'discount', 'market', 'order.date', 'order.id', 'order.priority',
#        'product.id', 'product.name', 'profit', 'quantity', 'region', 'row.id',
#        'sales', 'segment', 'ship.date', 'ship.mode', 'shipping.cost', 'state',
#        'sub.category', 'year', 'market2', 'weeknum'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(".","_")

# %%
df.columns
# Out:
# Index(['category', 'city', 'country', 'customer_id', 'customer_name',
#        'discount', 'market', 'order_date', 'order_id', 'order_priority',
#        'product_id', 'product_name', 'profit', 'quantity', 'region', 'row_id',
#        'sales', 'segment', 'ship_date', 'ship_mode', 'shipping_cost', 'state',
#        'sub_category', 'year', 'market2', 'weeknum'],
#       dtype='object')

# %%
df.describe(include="all"
            )
# Out:
#                category           city        country customer_id  \
# count             51290          51290          51290       51290
# unique                3           3636            147        4873
# top     Office Supplies  New York City  United States   JG-158051
# freq              31273            915           9994          40
# mean                NaN            NaN            NaN         NaN
# std                 NaN            NaN            NaN         NaN
# min                 NaN            NaN            NaN         NaN
# 25%                 NaN            NaN            NaN         NaN
# 50%                 NaN            NaN            NaN         NaN
# 75%                 NaN            NaN            NaN         NaN
# max                 NaN            NaN            NaN         NaN
#
#           customer_name      discount market               order_date  \
# count             51290  51290.000000  51290                    51290
# ...

# %%
df['country'].unique()
# Out:
# array(['United States', 'France', 'Germany', 'El Salvador', 'Guatemala',
#        'Austria', 'Nicaragua', 'Belgium', 'Switzerland', 'Italy',
#        'South Africa', 'India', 'Hong Kong',
#        'Democratic Republic of the Congo', 'Cuba', 'United Kingdom',
#        'Spain', 'Russia', 'China', 'Niger', 'Qatar', 'New Zealand',
#        'Mexico', 'Malaysia', 'Poland', 'Madagascar', 'Iraq', 'Brazil',
#        'Colombia', 'Saudi Arabia', 'Egypt', 'Iran', 'Ukraine', 'Japan',
#        'Morocco', 'Cameroon', 'Chile', 'Ghana', 'Trinidad and Tobago',
#        'Canada', 'Chad', 'Kenya', 'Bangladesh', 'Bulgaria', 'Djibouti',
#        'Uruguay', 'Singapore', 'Czech Republic', 'Zambia', 'Bolivia',
#        'Angola', 'Australia', 'Tanzania', 'Norway', 'Sierra Leone',
#        'Hungary', 'Ecuador', 'Finland', 'Afghanistan', 'Uzbekistan',
#        'Romania', 'Kyrgyzstan', 'Belarus', 'Mongolia', 'Georgia', 'Syria',
#        'Croatia', 'Israel', 'Liberia', 'Guinea-Bissau', 'Somalia',
# ...

# %%
(df['country']=='India').value_counts()
# Out:
# country
# False    49735
# True      1555
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        51290 non-null  object
#  1   city            51290 non-null  object
#  2   country         51290 non-null  object
#  3   customer_id     51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   discount        51290 non-null  float64
#  6   market          51290 non-null  object
#  7   order_date      51290 non-null  object
#  8   order_id        51290 non-null  object
#  9   order_priority  51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  product_name    51290 non-null  object
#  12  profit          51290 non-null  float64
#  13  quantity        51290 non-null  int64
#  14  region          51290 non-null  object
#  15  row_id          51290 non-null  int64
#  16  sales           51290 non-null  int64
# ...

# %%
#datatype of orderDate should be date
#datatype of ShipDate should be date
#year is of integer datatype

# %%
df['order_date']=pd.to_datetime(df['order_date'])
df['ship_date']=pd.to_datetime(df['ship_date'])
df['year']=df['year'].astype(str
                             )

# %%
df['order_date']
df['ship_date']
df['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 51285    2014
# 51286    2014
# 51287    2014
# 51288    2014
# 51289    2014
# Name: year, Length: 51290, dtype: object

# %%
df.drop_duplicates()
# Out:
#               category         city        country customer_id  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           customer_name  discount market order_date        order_id  \
# 0      Lycoris Saunders       0.0     US 2011-01-07  CA-2011-130813
# 1         Mark Van Huff       0.0     US 2011-01-21  CA-2011-148614
# ...

# %%
#EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        51290 non-null  object
#  1   city            51290 non-null  object
#  2   country         51290 non-null  object
#  3   customer_id     51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   discount        51290 non-null  float64
#  6   market          51290 non-null  object
#  7   order_date      51290 non-null  datetime64[ns]
#  8   order_id        51290 non-null  object
#  9   order_priority  51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  product_name    51290 non-null  object
#  12  profit          51290 non-null  float64
#  13  quantity        51290 non-null  int64
#  14  region          51290 non-null  object
#  15  row_id          51290 non-null  int64
#  16  sales           51290 non-null  int64
# ...

# %%
#Univariate Analysis
df['sales'].describe()
# Out:
# count    51290.000000
# mean       246.498440
# std        487.567175
# min          0.000000
# 25%         31.000000
# 50%         85.000000
# 75%        251.000000
# max      22638.000000
# Name: sales, dtype: float64

# %%
df['sales'].median()
# Out:
# np.float64(85.0)

# %%
sns.distplot(df['sales'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15232\1466740702.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sales'])
# <Axes: xlabel='sales', ylabel='Density'>

# %%
sns.histplot(df['sales'],log_scale=10)
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %%
sns.boxplot(df['sales'],orient='h',log_scale=10)
# Out:
# <Axes: xlabel='sales'>

# %%
df['profit'].describe()
# Out:
# count    51290.000000
# mean        28.610982
# std        174.340972
# min      -6599.978000
# 25%          0.000000
# 50%          9.240000
# 75%         36.810000
# max       8399.976000
# Name: profit, dtype: float64

# %%
sns.distplot(df['profit'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15232\2073238349.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['profit'])
# <Axes: xlabel='profit', ylabel='Density'>

# %%
sns.histplot(df['profit'],log_scale=10)
# Out:
# <Axes: xlabel='profit', ylabel='Count'>

# %%
sns.boxplot(df['profit'],orient='h')
# Out:
# <Axes: xlabel='profit'>

# %%
df['quantity'].describe()
# Out:
# count    51290.000000
# mean         3.476545
# std          2.278766
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max         14.000000
# Name: quantity, dtype: float64

# %%
sns.distplot(df['quantity'],hist=False)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15232\2003958352.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['quantity'],hist=False)
# <Axes: xlabel='quantity', ylabel='Density'>

# %%
sns.boxplot(df['quantity'],orient='h')
# Out:
# <Axes: xlabel='quantity'>

# %%
df['discount'].describe()
# Out:
# count    51290.000000
# mean         0.142908
# std          0.212280
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.200000
# max          0.850000
# Name: discount, dtype: float64

# %%
sns.distplot(df['discount'],hist=False)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15232\2747735562.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['discount'],hist=False)
# <Axes: xlabel='discount', ylabel='Density'>

# %%
sns.violinplot(df['discount'],orient='h')
# Out:
# <Axes: xlabel='discount'>

# %%
df['shipping_cost'].describe()
# Out:
# count    51290.000000
# mean        26.375818
# std         57.296810
# min          0.002000
# 25%          2.610000
# 50%          7.790000
# 75%         24.450000
# max        933.570000
# Name: shipping_cost, dtype: float64

# %%
sns.distplot(df['shipping_cost'],hist=False)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15232\1705491601.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['shipping_cost'],hist=False)
# <Axes: xlabel='shipping_cost', ylabel='Density'>

# %%
sns.boxplot(df['shipping_cost'],orient='h',log_scale=2)
# Out:
# <Axes: xlabel='shipping_cost'>

# %%
#Categorical Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        51290 non-null  object
#  1   city            51290 non-null  object
#  2   country         51290 non-null  object
#  3   customer_id     51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   discount        51290 non-null  float64
#  6   market          51290 non-null  object
#  7   order_date      51290 non-null  datetime64[ns]
#  8   order_id        51290 non-null  object
#  9   order_priority  51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  product_name    51290 non-null  object
#  12  profit          51290 non-null  float64
#  13  quantity        51290 non-null  int64
#  14  region          51290 non-null  object
#  15  row_id          51290 non-null  int64
#  16  sales           51290 non-null  int64
# ...

# %%
sns.barplot(df['category'].value_counts())
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
sns.barplot(df['sub_category'].value_counts(),orient='h')
# Out:
# <Axes: xlabel='count', ylabel='sub_category'>

# %%
sns.barplot(df['region'].value_counts(),orient='h')
# Out:
# <Axes: xlabel='count', ylabel='region'>

# %%
sns.catplot(df['segment'],kind='count')

# %%
sns.catplot(df['ship_mode'],kind='count')

# %%
sns.catplot(df['market'],kind='count')

# %%
df['month']=df['order_date'].dt.month_name
df['quarter']=df['order_date'].dt.quarter

# %%
df.head()
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    discount market order_date        order_id order_priority  ...  ship_date  \
# 0       0.0     US 2011-01-07  CA-2011-130813           High  ... 2011-01-09
# 1       0.0     US 2011-01-21  CA-2011-148614         Medium  ... 2011-01-26
# 2       0.0     US 2011-08-05  CA-2011-118962         Medium  ... 2011-08-09
# 3       0.0     US 2011-08-05  CA-2011-118962         Medium  ... 2011-08-09
# 4       0.0     US 2011-09-29  CA-2011-146969           High  ... 2011-10-03
#
# ...

# %%
df['month']=df['order_date'].dt.month_name()

# %%
df.head()
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    discount market order_date        order_id order_priority  ...  ship_date  \
# 0       0.0     US 2011-01-07  CA-2011-130813           High  ... 2011-01-09
# 1       0.0     US 2011-01-21  CA-2011-148614         Medium  ... 2011-01-26
# 2       0.0     US 2011-08-05  CA-2011-118962         Medium  ... 2011-08-09
# 3       0.0     US 2011-08-05  CA-2011-118962         Medium  ... 2011-08-09
# 4       0.0     US 2011-09-29  CA-2011-146969           High  ... 2011-10-03
#
# ...

# %%
df['YearMonth'] = df['order_date'].dt.to_period('M').astype(str)
monthly_sales = (
    df.groupby('YearMonth')['sales']
      .sum()
      .reset_index()
)

plt.figure(figsize=(14,5))

sns.lineplot(
    data=monthly_sales,
    x='YearMonth',
    y='sales',
    marker='o'
)

plt.xticks(rotation=90)
plt.title("Monthly Sales Trend")
plt.xlabel("Year-Month")
plt.ylabel("Total Sales")
plt.tight_layout()

plt.show()

# %%
df['month_num'] = df['order_date'].dt.month

# %%
df['month_num'].head()
# Out:
# 0    1
# 1    1
# 2    8
# 3    8
# 4    9
# Name: month_num, dtype: int32

# %%
df['YearQuarter'] = df['order_date'].dt.to_period('Q').astype(str)
monthly_sales = (
    df.groupby('YearQuarter')['sales']
      .sum()
      .reset_index()
)

plt.figure(figsize=(14,5))

sns.lineplot(
    data=monthly_sales,
    x='YearQuarter',
    y='sales',
    marker='o'
)

plt.xticks(rotation=90)
plt.title("Quarterly Sales Trend")
plt.xlabel("Year-Quarter")
plt.ylabel("Total Sales")
plt.tight_layout()

plt.show()

# %%
yearly_sales = (
    df.groupby('year')['sales']
      .sum()
      .reset_index()
)
plt.figure(figsize=(14,5))
sns.lineplot(
    data=yearly_sales,
    x='year',
    y='sales',
    marker='o'
)

plt.title("Yearly Sales Trend")
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.tight_layout()

# %%
sns.heatmap(df[['profit','sales','quantity','discount','shipping_cost']].corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,5))
sns.lineplot(x='sales',y='profit',data=df)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(14,5))
sns.lineplot(x='profit',y='discount',data=df)
plt.plot()

# %%
plt.figure(figsize=(14,5))
sns.lineplot(x='sales',y='quantity',data=df)
plt.plot()
# Out:
# []

# %%
avg_sales_by_category = df.groupby('category')['sales'].mean().reset_index()

sns.barplot(x='category',y='sales',data=avg_sales_by_category)
plt.title("Average Sales by Category")
plt.xlabel("Category")
plt.ylabel("Average Sales")
plt.tight_layout()

# %%
avg_profit_by_category = df.groupby('category')['profit'].mean().reset_index()

sns.barplot(x='category',y='profit',data=avg_profit_by_category)
plt.title("Average Profit by Category")
plt.xlabel("Category")
plt.ylabel("Average Profit")
plt.tight_layout()

# %%
avg_discount_by_category = df.groupby('category')['discount'].mean().reset_index()

sns.barplot(x='category',y='discount',data=avg_discount_by_category)
plt.title("Average discount by Category")
plt.xlabel("Category")
plt.ylabel("Average discount")
plt.tight_layout()

# %%
avg_order_quantity_by_region=df.groupby('region')['quantity'].mean().reset_index()
sns.barplot(y='region',x='quantity',data=avg_order_quantity_by_region)
plt.title("Average Order Quantity by Region")
plt.ylabel("Region")
plt.xlabel("Average Order Quantity")
plt.tight_layout()

# %%
avg_sales_by_region = df.groupby('region')['sales'].mean().reset_index()

sns.barplot(y='region',x='sales',data=avg_sales_by_region)
plt.title("Average Sales by Region")
plt.ylabel("Region")
plt.xlabel("Average Sales")
plt.tight_layout()

# %%
avg_profit_by_region = df.groupby('region')['profit'].mean().reset_index()

sns.barplot(y='region',x='profit',data=avg_profit_by_region)
plt.title("Average Profit by Region")
plt.plot()
# Out:
# []

# %%
#No of unique customer
len(df['customer_name'].unique())
# Out:
# 795

# %%
#top 10 customers
df['customer_name'].value_counts().head(10)
# Out:
# customer_name
# Muhammed Yedwab    108
# Steven Ward        106
# Patrick O'Brill    102
# Bill Eplett        102
# Gary Hwang         102
# Harry Greene       101
# Eric Murdock       100
# Art Ferguson        98
# Brosina Hoffman     97
# Bart Watters        96
# Name: count, dtype: int64

# %%
df.head()
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    discount market order_date        order_id order_priority  ...       state  \
# 0       0.0     US 2011-01-07  CA-2011-130813           High  ...  California
# 1       0.0     US 2011-01-21  CA-2011-148614         Medium  ...  California
# 2       0.0     US 2011-08-05  CA-2011-118962         Medium  ...  California
# 3       0.0     US 2011-08-05  CA-2011-118962         Medium  ...  California
# 4       0.0     US 2011-09-29  CA-2011-146969           High  ...  California
#
# ...

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# PostgreSQL Credentials
username = "postgres"
password = "Maths@29115"      # Replace with your password
host = "localhost"
port = 5432
database = "Sales_Analytics"

# Create connection URL
url = URL.create(
    drivername="postgresql+psycopg2",
    username=username,
    password=password,
    host=host,
    port=port,
    database=database
)

# Create engine
engine = create_engine(url)

# %%
try:
    with engine.connect() as conn:
        print("✅ Connected to PostgreSQL successfully!")
except Exception as e:
    print("❌ Connection failed!")
    print(e)
# Out:
# ✅ Connected to PostgreSQL successfully!

# %%
df.to_sql(
    name='sales',
    con=engine,
    if_exists='replace',
    index=False
)

print("✅ Data uploaded successfully!")
# Out:
# ✅ Data uploaded successfully!
